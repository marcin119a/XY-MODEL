# %%
from importlib import reload  # Python 3.4+
import Ising_model
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import uniform
from scipy.stats import binom
reload(Ising_model)
# Out:
# <module 'Ising_model' from '/Users/mw/PycharmProjects/xymodel-st-data/XY-MODEL/Ising_model.py'>

# %%
nSpots = 841
nTypes = 10 
from Ising_model import IsingSystem

prior_pi = uniform.rvs(loc=0, scale=1, size=(nSpots, nTypes), random_state=None)

prior_Z = binom.rvs(1, prior_pi)


xy_system_1 = IsingSystem(temperature=10, spin_config=prior_Z)
thetas_set = xy_system_1.equilibrate(show=True)
# Out:
# sweeps=101
# energy=-0.008323424494649227
#
# equilibrium state is reached at T=0.2
# #sweep=999
# energy=-0.011890606420927468
